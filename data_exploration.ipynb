# %%
# Set working directory to parent/src
import os
from pathlib import Path

# Navigate to parent/src (one level up from current notebook location)
notebook_dir = Path.cwd()
project_root = notebook_dir.parent  # Go to marinetime-project/
src_dir = project_root    # Then to marinetime-project/src/

os.chdir(src_dir)
print(f"Working directory set to: {os.getcwd()}")
# Out:
# Working directory set to: /Users/madshaakonsson/Desktop/DL/marinetime-project

# %% [markdown]
# # Notebook Exploration of data

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
import pandas as pd 
from src.streamer import BatchStream 
from mlflow.tracking import MlflowClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 from src.streamer import BatchStream
#       3 from mlflow.tracking import MlflowClient
#
# File ~/Desktop/DL/marinetime-project/src/streamer.py:1
# ----> 1 from google_drive_fetcher import GoogleDriveFetcher
#       2 import torch
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'google_drive_fetcher'

# %% [markdown]
# # Loading models and data

# %%
ports_df = pd.read_csv("./port_counts.csv")  
port_encoder = {port_name: i for i, port_name in enumerate(ports_df["Port"])} 

ports_df["Count"].sum()
# Out:
# np.int64(1279)

# %% [markdown]
# ## Loading run

# %%
client = MlflowClient()            # or MlflowClient(tracking_uri)
experiment_id = "964646345580301318"

exp = MlflowClient().get_experiment(experiment_id) 
#runs = MlflowClient().search_runs(experiment_id)
# Out:
# /Users/madshaakonsson/Desktop/DL/marinetime-project/.venv/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:140: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, store_uri)
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 client = MlflowClient()            # or MlflowClient(tracking_uri)
#       2 experiment_id = "964646345580301318"
# ----> 4 exp = MlflowClient().get_experiment(experiment_id)
#       5 #runs = MlflowClient().search_runs(experiment_id)
#
# File ~/Desktop/DL/marinetime-project/.venv/lib/python3.11/site-packages/mlflow/tracking/client.py:1764, in MlflowClient.get_experiment(self, experiment_id)
# ...
