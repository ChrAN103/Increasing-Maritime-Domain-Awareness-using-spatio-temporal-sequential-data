# %% [markdown]
# # Test of Google Drive Fetcher

# %%
from google_drive_fetcher import GoogleDriveFetcher 

gdf = GoogleDriveFetcher()
folder_url = "https://drive.google.com/drive/folders/1PKdRw01LZYVkb0a2ok--oBuudSFepyQU?hl=da"

# %%
gdf.list_directory(folder_url=folder_url)
# Out:
# [{'id': '1YPvWsE2kAw1PZ-_S_nIl1dj6PMyzozDe',
#   'name': 'aisdk-2023-01-01.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1YPvWsE2kAw1PZ-_S_nIl1dj6PMyzozDe/view'},
#  {'id': '1NlnKO8D7KLrD8v6UeQm8wIWm4GJ8nPmZ',
#   'name': 'aisdk-2023-01-02.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1NlnKO8D7KLrD8v6UeQm8wIWm4GJ8nPmZ/view'},
#  {'id': '1R8PD_f-tJXY4MrdcURvIeWMGdMkJCUOc',
#   'name': 'aisdk-2023-01-03.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1R8PD_f-tJXY4MrdcURvIeWMGdMkJCUOc/view'},
#  {'id': '1k9q1MENTiXgvADJfvLhAF42qrcJw-vVI',
#   'name': 'aisdk-2023-01-04.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1k9q1MENTiXgvADJfvLhAF42qrcJw-vVI/view'},
#  {'id': '1QkDzyqItIiPm6F7uat2blOqRXcvKQyUz',
#   'name': 'aisdk-2023-01-05.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1QkDzyqItIiPm6F7uat2blOqRXcvKQyUz/view'},
#  {'id': '1Ag_7vfJ_ixDW4Fem85q0LdqpZJCeovpO',
#   'name': 'aisdk-2023-01-06.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1Ag_7vfJ_ixDW4Fem85q0LdqpZJCeovpO/view'},
#  {'id': '1OmZT4DQMy5rxrX0lR6mB0CncLz2ab489',
#   'name': 'aisdk-2023-01-07.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1OmZT4DQMy5rxrX0lR6mB0CncLz2ab489/view'},
#  {'id': '1CbQUDB9eTzaqbRLfuyQ9pKrnV0DRvCYx',
#   'name': 'aisdk-2023-01-08.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1CbQUDB9eTzaqbRLfuyQ9pKrnV0DRvCYx/view'},
#  {'id': '19feXvQsfUy4x7Gtg1n766ANNHVJURRQB',
#   'name': 'aisdk-2023-01-09.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/19feXvQsfUy4x7Gtg1n766ANNHVJURRQB/view'},
#  {'id': '1oyoozgaZIgkjfG56r5r9N8WgVNHCB_Mi',
#   'name': 'aisdk-2023-01-10.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1oyoozgaZIgkjfG56r5r9N8WgVNHCB_Mi/view'},
#  {'id': '1BYnjFx0lZ3nhEURFO1EVj9hl7oMVJYQU',
#   'name': 'aisdk-2023-01-11.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1BYnjFx0lZ3nhEURFO1EVj9hl7oMVJYQU/view'},
#  {'id': '1iOd1f0D8GnCyleT_uFDApgqFYvbooNcN',
#   'name': 'aisdk-2023-01-12.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1iOd1f0D8GnCyleT_uFDApgqFYvbooNcN/view'},
#  {'id': '1J4dwz0k6aEU64_2k3sXtZxhT4AbbRxED',
#   'name': 'aisdk-2023-01-13.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1J4dwz0k6aEU64_2k3sXtZxhT4AbbRxED/view'},
#  {'id': '17Eo4bRrBse4lGPhTToB_UpWdV2C48hH4',
#   'name': 'aisdk-2023-01-14.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/17Eo4bRrBse4lGPhTToB_UpWdV2C48hH4/view'},
#  {'id': '1d35NEI87GBmCT5MP7gJepb9Sslc-a2Ty',
#   'name': 'aisdk-2023-01-15.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1d35NEI87GBmCT5MP7gJepb9Sslc-a2Ty/view'},
#  {'id': '1ebHCRdJ0f0HmT_CWmpLYKeGMU1w0ruHg',
#   'name': 'aisdk-2023-01-16.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1ebHCRdJ0f0HmT_CWmpLYKeGMU1w0ruHg/view'},
#  {'id': '1MQZs6oI5eSfLkKyArctlzeWSisJF6Tcn',
#   'name': 'aisdk-2023-01-17.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1MQZs6oI5eSfLkKyArctlzeWSisJF6Tcn/view'},
#  {'id': '1lkT8cNaM9zPQZdhOvUdqmBBoAXyuG7Qw',
#   'name': 'aisdk-2023-01-18.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1lkT8cNaM9zPQZdhOvUdqmBBoAXyuG7Qw/view'},
#  {'id': '1pc31pw7xWreJpm82YtC2aUjCsL8gsYZf',
#   'name': 'aisdk-2023-01-19.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1pc31pw7xWreJpm82YtC2aUjCsL8gsYZf/view'},
#  {'id': '1bNdKRZU0QVNB8H52fGLTKBpvLbOBx3Ty',
#   'name': 'aisdk-2023-01-20.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1bNdKRZU0QVNB8H52fGLTKBpvLbOBx3Ty/view'},
#  {'id': '1W1Bf2cjcY6hEWzKgsOqIW9Hy7r0qSkFA',
#   'name': 'aisdk-2023-01-21.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1W1Bf2cjcY6hEWzKgsOqIW9Hy7r0qSkFA/view'},
#  {'id': '1U0yed5HlC46sxtTeyiCgd3R3IkHXRwFR',
#   'name': 'aisdk-2023-01-22.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1U0yed5HlC46sxtTeyiCgd3R3IkHXRwFR/view'},
#  {'id': '1B-BKjmgIHQQ7BIj1E2iQgdOh8OBBk6YH',
#   'name': 'aisdk-2023-01-23.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1B-BKjmgIHQQ7BIj1E2iQgdOh8OBBk6YH/view'},
#  {'id': '1e7mxeR2ZcVlG1U0zIpBubcglY3jqhXsI',
#   'name': 'aisdk-2023-01-24.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1e7mxeR2ZcVlG1U0zIpBubcglY3jqhXsI/view'},
#  {'id': '1X2U781K1DFkKodX_sh1dLo81MXLlUQkh',
#   'name': 'aisdk-2023-01-25.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1X2U781K1DFkKodX_sh1dLo81MXLlUQkh/view'},
#  {'id': '1vNufFa1Ex5VHAyEnndjYjkyXa5pqLiOK',
#   'name': 'aisdk-2023-01-26.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1vNufFa1Ex5VHAyEnndjYjkyXa5pqLiOK/view'},
#  {'id': '1rTTDFvQv1H2RLdFlRtbS2siI9a-PG4R0',
#   'name': 'aisdk-2023-01-27.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1rTTDFvQv1H2RLdFlRtbS2siI9a-PG4R0/view'},
#  {'id': '1PJU880vQQQ-OCv_Tmt9U2Ide9WjKqlL6',
#   'name': 'aisdk-2023-01-28.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1PJU880vQQQ-OCv_Tmt9U2Ide9WjKqlL6/view'},
#  {'id': '1D8RPHpZ2GzSE-c_f1JBM9unBRYqIALU9',
#   'name': 'aisdk-2023-01-29.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1D8RPHpZ2GzSE-c_f1JBM9unBRYqIALU9/view'},
#  {'id': '13pQ9A8KkQRQMG7G4VeTqE_sgZYfsunog',
#   'name': 'aisdk-2023-01-30.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/13pQ9A8KkQRQMG7G4VeTqE_sgZYfsunog/view'},
#  {'id': '1rzBLNdRsP7FazlzDm3Wy_2ZSUyZax3Ws',
#   'name': 'aisdk-2023-01-31.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1rzBLNdRsP7FazlzDm3Wy_2ZSUyZax3Ws/view'},
#  {'id': '1tcSCb5MU02qLnAvw9GHhaUbyWm_k397P',
#   'name': 'aisdk-2023-02-01.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1tcSCb5MU02qLnAvw9GHhaUbyWm_k397P/view'},
#  {'id': '1znKNHVJt7gvk3FcocrleJwSm40EmAHq3',
#   'name': 'aisdk-2023-02-02.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1znKNHVJt7gvk3FcocrleJwSm40EmAHq3/view'},
#  {'id': '1K_4tKe986k17q4LSIgzVnVHgUzKHqRfv',
#   'name': 'aisdk-2023-02-03.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1K_4tKe986k17q4LSIgzVnVHgUzKHqRfv/view'},
#  {'id': '1S4za0rQCwfiZ4Cn3tSaP56pS7Ki5NSoF',
#   'name': 'aisdk-2023-02-04.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1S4za0rQCwfiZ4Cn3tSaP56pS7Ki5NSoF/view'},
#  {'id': '1HnAxpO61XcY1DRP83_XaKvh10XsKOGuS',
#   'name': 'aisdk-2023-02-05.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1HnAxpO61XcY1DRP83_XaKvh10XsKOGuS/view'},
#  {'id': '1IM33ZIHV1izMxvhTTyj0UnkCIS_plZPR',
#   'name': 'aisdk-2023-02-06.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1IM33ZIHV1izMxvhTTyj0UnkCIS_plZPR/view'},
#  {'id': '1b32WtlE75C_jism90DxdNHTuBmuLflrw',
#   'name': 'aisdk-2023-02-07.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1b32WtlE75C_jism90DxdNHTuBmuLflrw/view'},
#  {'id': '1d-HFKvuk-KhGm-l9MCL-6WPGjmlMJl16',
#   'name': 'aisdk-2023-02-08.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1d-HFKvuk-KhGm-l9MCL-6WPGjmlMJl16/view'},
#  {'id': '1PGuuMfpWH49hvuG_hwvW0fd7SQLm7FMQ',
#   'name': 'aisdk-2023-02-09.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1PGuuMfpWH49hvuG_hwvW0fd7SQLm7FMQ/view'},
#  {'id': '1yVu5Ve5Lrir9k8xji9U8iijcPT9ZMdbP',
#   'name': 'aisdk-2023-02-10.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1yVu5Ve5Lrir9k8xji9U8iijcPT9ZMdbP/view'},
#  {'id': '1F6USivZdrFtuxlykcx-N9nIEQ3PS4Njv',
#   'name': 'aisdk-2023-02-11.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1F6USivZdrFtuxlykcx-N9nIEQ3PS4Njv/view'},
#  {'id': '1mRe20NFnuo5iW1kDr4BF95fOzPrEkcmZ',
#   'name': 'aisdk-2023-02-12.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1mRe20NFnuo5iW1kDr4BF95fOzPrEkcmZ/view'},
#  {'id': '1CjgDFeTnG-Bg9XNH0IJwQgS1_kN5nCAd',
#   'name': 'aisdk-2023-02-13.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1CjgDFeTnG-Bg9XNH0IJwQgS1_kN5nCAd/view'},
#  {'id': '1dpZcjJZPNr6hbuereaWTteiRzqT-mP0Q',
#   'name': 'aisdk-2023-02-14.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1dpZcjJZPNr6hbuereaWTteiRzqT-mP0Q/view'},
#  {'id': '1LxTba5A_L3rOAk1vqDglGsAszOFF5tfL',
#   'name': 'aisdk-2023-02-15.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1LxTba5A_L3rOAk1vqDglGsAszOFF5tfL/view'},
#  {'id': '18-YC-kJqApACluhDL4-m8g1CJaTqmKRY',
#   'name': 'aisdk-2023-02-16.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/18-YC-kJqApACluhDL4-m8g1CJaTqmKRY/view'},
#  {'id': '1JL3KpoSqWTESCmeViawXKAovaeXTleU6',
#   'name': 'aisdk-2023-02-17.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1JL3KpoSqWTESCmeViawXKAovaeXTleU6/view'},
#  {'id': '1vZ1sNNI2ye3af6ISUHjXnVjSY0-OPQLX',
#   'name': 'aisdk-2023-02-18.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/1vZ1sNNI2ye3af6ISUHjXnVjSY0-OPQLX/view'},
#  {'id': '18imX1t0ShLcw4PQ7WvQOjSkAtROttELD',
#   'name': 'aisdk-2023-02-19.parquet Shared folder',
#   'type': 'file',
#   'url': 'https://drive.google.com/file/d/18imX1t0ShLcw4PQ7WvQOjSkAtROttELD/view'}]

# %% [markdown]
# # Example: Download Parquet File and Convert to DataFrame
#
# The `GoogleDriveFetcher` class provides two ways to convert parquet files to pandas DataFrames:
#
# 1. **Direct conversion from URL**: `fetch_parquet_to_dataframe(url)` - Downloads and converts in one step
# 2. **Download from folder**: `download_parquet_from_folder(folder_url, filename, return_dataframe=True)` - Finds and converts a specific file in a folder

# %%
# First, let's see what files are actually in the folder
folder_url = "https://drive.google.com/drive/folders/1v4zupQQfvN_7ueft265XDrCrZj6fTRZR?hl=da"

print("Listing files in the folder...")
items = gdf.list_directory(folder_url)
print(f"\nFound {len(items)} items:\n")

# List all parquet FILES (not folders)
parquet_files = [item for item in items if item['name'].endswith('.parquet') and item['type'] == 'file']
print(f"Parquet files ({len(parquet_files)}):")
for item in parquet_files:
    print(f"  - {item['name']}")

# List folders (including those ending with .parquet)
folders = [item for item in items if item['type'] == 'folder']
print(f"\nFolders ({len(folders)}):")
for item in folders:
    print(f"  - {item['name']}")
# Out:
# Listing files in the folder...
#
# Found 1 items:
#
# Parquet files (0):
#
# Folders (0):
#
# Found 1 items:
#
# Parquet files (0):
#
# Folders (0):

# %%
# Navigate into the .parquet folders to find the actual files
print("\n" + "="*60)
print("Looking inside .parquet folders...")
print("="*60)

all_parquet_files = []

for folder in folders:
    if '.parquet' in folder['name']:
        print(f"\n📁 Exploring folder: {folder['name']}")
        try:
            # Navigate into the folder
            folder_contents = gdf.list_directory(folder['url'])
            
            # Find parquet files in this folder
            files_in_folder = [item for item in folder_contents if item['type'] == 'file' and item['name'].endswith('.parquet')]
            
            print(f"   Found {len(files_in_folder)} parquet file(s):")
            for file in files_in_folder:
                print(f"      - {file['name']}")
                all_parquet_files.append({
                    'name': file['name'],
                    'url': file['url'],
                    'folder': folder['name']
                })
        except Exception as e:
            print(f"   Error accessing folder: {e}")

print(f"\n{'='*60}")
print(f"Total parquet files found across all folders: {len(all_parquet_files)}")
print(f"{'='*60}")
# Out:
# ============================================================
# Looking inside .parquet folders...
# ============================================================
#
# ============================================================
# Total parquet files found across all folders: 0
# ============================================================

# %%
# Now download a parquet file from inside the folders
if all_parquet_files:
    # Get the first file
    file_info = all_parquet_files[0]
    print(f"\nDownloading '{file_info['name']}' from folder '{file_info['folder']}'...")
    
    try:
        # Use the direct URL method since we have it
        df = gdf.fetch_parquet_to_dataframe(file_info['url'])
        
        print(f"\n✓ Successfully loaded DataFrame!")
        print(f"Shape: {df.shape} (rows: {df.shape[0]}, columns: {df.shape[1]})")
        print(f"\nColumns: {list(df.columns)}")
        print(f"\nFirst few rows:")
        print(df.head())
        print(f"\nData types:")
        print(df.dtypes)
        
    except Exception as e:
        print(f"Error: {e}")
else:
    print("\nNo parquet files found in any folders!")
# Out:
# No parquet files found in any folders!

# %%
# Now let's download the first parquet file we find
if parquet_files:
    filename = parquet_files[0]['name']  # Use the actual filename from the folder
    print(f"\n\nDownloading '{filename}' and converting to DataFrame...")
    
    try:
        df = gdf.download_parquet_from_folder(
            folder_url=folder_url,
            file_name=filename,
            return_dataframe=True
        )
        
        if df is not None:
            print(f"\n✓ Successfully loaded DataFrame!")
            print(f"Shape: {df.shape} (rows: {df.shape[0]}, columns: {df.shape[1]})")
            print(f"\nColumns: {list(df.columns)}")
            print(f"\nFirst few rows:")
            print(df.head())
            print(f"\nData types:")
            print(df.dtypes)
        else:
            print(f"File '{filename}' not found in folder")
            
    except Exception as e:
        print(f"Error: {e}")
else:
    print("\nNo parquet files found in the folder!")
# Out:
# No parquet files found in the folder!

# %%
# Alternative Method: If you know the exact filename, use it directly
# (Make sure to run the listing cell above first to get the actual filename)

# Example: Replace 'your-file.parquet' with an actual filename from the listing above
specific_filename = "17dd8e3b4a914443bb1cb5d0ea850a61-0.parquet"  # Update this with actual filename

try:
    print(f"Attempting to download '{specific_filename}'...")
    df_specific = gdf.download_parquet_from_folder(
        folder_url=folder_url,
        file_name=specific_filename,
        return_dataframe=True
    )
    
    if df_specific is not None:
        print(f"✓ Successfully loaded!")
        print(f"Shape: {df_specific.shape}")
    else:
        print(f"⚠ File '{specific_filename}' not found. Check the listing above for available files.")
        
except Exception as e:
    print(f"Error: {e}")
# Out:
# Attempting to download '17dd8e3b4a914443bb1cb5d0ea850a61-0.parquet'...
# ⚠ File '17dd8e3b4a914443bb1cb5d0ea850a61-0.parquet' not found. Check the listing above for available files.
# ⚠ File '17dd8e3b4a914443bb1cb5d0ea850a61-0.parquet' not found. Check the listing above for available files.

# %%
# Method 2: Direct conversion from file URL
# First, get the file URL from the directory listing (uses 'items' from above)
if parquet_files:
    file_url = parquet_files[0]['url']
    filename_direct = parquet_files[0]['name']
    
    try:
        print(f"\nUsing direct URL conversion for '{filename_direct}'...")
        df2 = gdf.fetch_parquet_to_dataframe(file_url)
        print(f"✓ Successfully loaded DataFrame directly!")
        print(f"Shape: {df2.shape}")
        print(f"\nFirst 3 rows:")
        print(df2.head(3))
    except Exception as e:
        print(f"Error: {e}")
else:
    print("No parquet files found in the folder!")
# Out:
# No parquet files found in the folder!

# %% [markdown]
# ## Alternative: Download to Disk Instead
#
# If you want to save the parquet file to disk instead of loading it directly to memory, set `return_dataframe=False`:

# %%
# Download to disk, then load with pandas
import pandas as pd

if parquet_files:
    filename_disk = parquet_files[0]['name']
    
    saved_path = gdf.download_parquet_from_folder(
        folder_url=folder_url,
        file_name=filename_disk,
        return_dataframe=False  # Save to ./downloads/ directory
    )
    
    if saved_path:
        print(f"File saved to: {saved_path}")
        # Load it manually with pandas
        df3 = pd.read_parquet(saved_path)
        print(f"Loaded DataFrame from disk with shape: {df3.shape}")
    else:
        print("File not found")
else:
    print("No parquet files available to download")
# Out:
# File not found

# %% [markdown]
# # Simple Test: Access Parquet File from Nested Directories
#
# This test navigates through subdirectories to find and load parquet files.

# %%
# Simple function to find and load the first parquet file
def find_and_load_first_parquet(base_url, max_depth=3, current_depth=0):
    """
    Recursively search through directories to find the first parquet file.
    
    Args:
        base_url: Google Drive folder URL
        max_depth: Maximum depth to search (default 3)
        current_depth: Current recursion depth
    
    Returns:
        pandas DataFrame or None
    """
    if current_depth >= max_depth:
        return None
    
    print("  " * current_depth + f"🔍 Searching at depth {current_depth}...")
    
    try:
        items = gdf.list_directory(base_url)
        
        # First, check for parquet files at this level
        for item in items:
            if item['type'] == 'file' and item['name'].endswith('.parquet'):
                print("  " * current_depth + f"✓ Found: {item['name']}")
                return gdf.fetch_parquet_to_dataframe(item['url'])
        
        # If no files found, search subdirectories
        for item in items:
            if item['type'] == 'folder':
                print("  " * current_depth + f"📁 Entering: {item['name']}")
                result = find_and_load_first_parquet(item['url'], max_depth, current_depth + 1)
                if result is not None:
                    return result
        
        return None
    except Exception as e:
        print("  " * current_depth + f"❌ Error: {e}")
        return None


# Test with your parent directory
parent_url = "https://drive.google.com/drive/folders/1ZPUA8ZUcVKuJWJGo69OaD6W1al8IbDyi?hl=da"

print("Starting search for parquet files...\n")
df_test = find_and_load_first_parquet(parent_url)

if df_test is not None:
    print("\n" + "="*60)
    print("✓ SUCCESS! Loaded DataFrame")
    print("="*60)
    print(f"Shape: {df_test.shape}")
    print(f"Columns: {list(df_test.columns)}")
    print(f"\nFirst 5 rows:")
    print(df_test.head())
else:
    print("\n❌ No parquet files found")
# Out:
# Starting search for parquet files...
#
# 🔍 Searching at depth 0...
#
# ❌ No parquet files found
#
# ❌ No parquet files found
